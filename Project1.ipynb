# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
income_df = pd.read_csv(r"C:\Users\wstod\OneDrive\Desktop\tableA12021.csv")
fast_food_df = pd.read_csv(r"C:\Users\wstod\OneDrive\Desktop\top_50_fast_food_chains.csv")
fast_food_df_2020 = pd.read_csv(r"C:\Users\wstod\OneDrive\Desktop\Top_50_fast_food_2020.csv")


print(income_df.head())
print(fast_food_df.head())
print(fast_food_df_2020.head())
# Out:
#   Table with row headers in column A and column headers in rows 4 through 6  \
# 0  Table A-1.\nIncome Summary Measures by Selecte...
# 1  (Income in 2021 dollars, adjusted using the R-...
# 2                                     Characteristic
# 3                                                NaN
# 4                                                NaN
#
#            Unnamed: 1                Unnamed: 2            Unnamed: 3  \
# 0                 NaN                       NaN                   NaN
# 1                 NaN                       NaN                   NaN
# 2              2020 1                       NaN                   NaN
# 3  Number (thousands)  Median income\n(dollars)                   NaN
# 4                 NaN                  Estimate  Margin of error2 (±)
#
#            Unnamed: 4                Unnamed: 5            Unnamed: 6  \
# 0                 NaN                       NaN                   NaN
# ...

# %%
income_df.dropna()
# Out:
#    Table with row headers in column A and column headers in rows 4 through 6  \
# 6                                      All households
# 8                                   Family households
# 9                                   ...Married-couple
# 10           ...Female householder, no spouse present
# 11             ...Male householder, no spouse present
# 12                               Nonfamily households
# 13                              ...Female householder
# 14                                ...Male householder
# 16                                              White
# 17                             ...White, not Hispanic
# 18                                              Black
# 19                                              Asian
# 20                                Hispanic (any race)
# 22                                     Under 65 years
# 23                                  ...15 to 24 years
# 24                                  ...25 to 34 years
# ...

# %%
income_df = income_df.rename(columns={'Table with row headers in column A and column headers in rows 4 through 6': 'Types of Households',
                                      'Unnamed: 1': '2020 Number of Households (Thousands)',
                                      'Unnamed: 2': '2020 Median Income',
                                      'Unnamed: 3': '2020 Margin of Error',
                                      'Unnamed: 4': '2021 Number of Households (Thousands)',
                                      'Unnamed: 5': '2021 Median Income',
                                      'Unnamed: 6': '2021 Margin of Error',
                                      'Unnamed: 7': 'Percent Change 2020 to 2021',
                                      'Unnamed: 8': 'Estimated Margin of Error for Percent Change'})

income_df.dropna()
# Out:
#                          Types of Households  \
# 6                             All households
# 8                          Family households
# 9                          ...Married-couple
# 10  ...Female householder, no spouse present
# 11    ...Male householder, no spouse present
# 12                      Nonfamily households
# 13                     ...Female householder
# 14                       ...Male householder
# 16                                     White
# 17                    ...White, not Hispanic
# 18                                     Black
# 19                                     Asian
# 20                       Hispanic (any race)
# 22                            Under 65 years
# 23                         ...15 to 24 years
# 24                         ...25 to 34 years
# 25                         ...35 to 44 years
# 26                         ...45 to 54 years
# 27                         ...55 to 64 years
# 28                        65 years and older
# ...

# %%
# Data from both years median incomes per household type
data = {'2020 Median Income': [71186, 90722, 106582, 51554, 70478, 42607, 37516, 49625, 74978, 78912, 48175, 99622, 58015, 80456, 49094, 74958, 89711, 94633, 77872, 48866, 72552, 65061, 72467, 57804, 79032, 70528, 64355, 78755, 74622, 65609, 80017, 54300, 73013, 31130, 49965, 67075, 112393],
        '2021 Median Income': [70784, 91162, 106921, 51168, 70525, 41797, 35737, 49466, 74262, 77999, 48297, 101418, 57981, 80734, 51645, 74862, 90312, 97089, 75842, 47620, 71522, 66043, 74150, 57132, 77472, 71129, 63368, 79430, 73823, 64839, 79599, 53750, 72046, 30378, 50401, 64378, 115456]}
df = pd.DataFrame(data)

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the data for both years on the same graph
df.plot(kind='bar', ax=ax, width=0.4)
plt.legend(loc="upper left")
plt.legend(fontsize=8)

# Set labels and title
ax.set_xlabel('Household Types')
ax.set_ylabel('Median Income Per Household Type')
ax.set_title('Comparison of Household Income: 2020 vs 2021')


# Set x-axis labels to display types of households 
ax.set_xticklabels(['All Households',
                    'Family Households',
                    'Married-Couple', 
                    'Female Householder, no spouse', 
                    'Male Householder, no spouse',
                    'Nonfamily households',
                    'Female Householder',
                    'Male Householder',
                    'White',
                    'White, not Hispanic',
                    'Black',
                    'Asian',
                    'Hispanic (any race)',
                    'Under 65 Years',
                    '15 to 24 years',
                    '25 to 34 years',
                    '35 to 44 years',
                    '45 to 54 years',
                    '55 to 64 years',
                    'Over 65 years',
                    'Native-Born',
                    'Foreign-born',
                    'Naturalized Citizen',
                    'Not a citizen',
                    'Northeast',
                    'Midwest',
                    'South',
                    'West',
                    'Inside Metro statistical areas',
                    'Inside Principal Cities',
                    'Outside Principal Cities',
                    'Outside Metro Statistical areas',
                    'Total, age 25 and older',
                    'No high school diploma',
                    'High School, no college',
                    'Some college',
                    'Bachelors degree or higher'], fontsize=8)

# Show the plot
plt.tight_layout()
plt.show()

# %%
fast_food_df.dropna()
# Out:
#                           Fast-Food Chains  \
# 0                                   Arby's
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl's Jr.
# 5                         Checkers/Rally's
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church's Chicken
# 9                                 Culver's
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy's Frozen Custard & Steakburgers
# 18                                Hardee's
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# ...

# %%
fast_food_df = fast_food_df.rename(columns={'U.S. Systemwide Sales (Millions - U.S Dollars)': 'U.S. Systemwide Sales 2021 (Millions - U.S Dollars)', 'Average Sales per Unit (Thousands - U.S Dollars)': 'Average Sales per Unit 2021 (Thousands - U.S Dollars)'})
fast_food_df
# Out:
#                           Fast-Food Chains  \
# 0                                   Arby's
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl's Jr.
# 5                         Checkers/Rally's
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church's Chicken
# 9                                 Culver's
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy's Frozen Custard & Steakburgers
# 18                                Hardee's
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# ...

# %%
fast_food_df_2020.dropna()
# Out:
#                           Fast-Food Chains  \
# 0                                   Arby's
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl's Jr.
# 5                         Checkers/Rally's
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church's Chicken
# 9                                 Culver's
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy's Frozen Custard & Steakburgers
# 18                                Hardee's
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# ...

# %%
merged_fast_food = pd.merge(fast_food_df,fast_food_df_2020, on="Fast-Food Chains")
merged_fast_food
# Out:
#                           Fast-Food Chains  \
# 0                                   Arby's
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl's Jr.
# 5                         Checkers/Rally's
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church's Chicken
# 9                                 Culver's
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy's Frozen Custard & Steakburgers
# 18                                Hardee's
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# ...

# %%
# Data from both years average sales systemwide in the US
data = {'U.S. Systemwide Sales 2020': [4215, 620, 1374, 9657, 1500, 854, 12800, 5985, 741, 1986, 3978, 857, 8287, 8762, 880, 840, 1711, 643, 2000, 1100, 3673, 1595, 1925, 4700, 830, 4000, 760, 625, 40518, 561, 3817, 5500, 3198, 805, 5400, 4587, 787, 1722, 5680, 18750, 8318, 11000, 702, 690, 10231, 2698, 565, 2000, 2000],
        'U.S. Systemwide Sales 2021': [4462, 686, 1485, 10033, 1560, 931, 16700, 7547, 776, 2489, 4494, 931, 8641, 10416, 973, 1044, 2093, 759, 2100, 1175, 4077, 2203, 2301, 5100, 996, 4185, 899, 869, 45960, 661, 4452, 5650, 3486, 809, 5500, 4775, 835, 2377, 5835, 24300, 9350, 12600, 687, 948, 11111, 3089, 615, 2278, 2233]}
df1 = pd.DataFrame(data)
# Create a figure and axis
fig, ax = plt.subplots()

# Plot the data for both years on the same graph
df1.plot(kind='bar', ax=ax, width=0.4)
plt.legend(loc="upper left", fontsize=8)

# Set labels and title
ax.set_xlabel('Fast Food Chains')
ax.set_ylabel('Systemwide sales (in millions)')
ax.set_title('Comparison of Top 50 Fast Food Chain Sales: 2020 vs 2021')


# Set x-axis labels to display types of households 
ax.set_xticklabels(['Arbys',
                    'Baskin-Robbins',
                    'Bojangles', 
                    'Burger King', 
                    'Carls Jr.',
                    'Checkers/Rallys',
                    'Chick-Fil-A',
                    'Chipotle',
                    'Churchs Chicken',
                    'Culvers',
                    'Dairy Queen',
                    'Del Taco',
                    'Dominos',
                    'Dunkin',
                    'El Pollo Loco',
                    'Firehouse Subs',
                    'Five Guys',
                    'Freddys Frozen Custard & Steakburgers',
                    'Hardees',
                    'In-N-Out Burger',
                    'Jack in the Box',
                    'Jersey Mikes',
                    'Jimmy Johns',
                    'KFC',
                    'Krispy Kreme',
                    'Little Caesars',
                    'Marcos Pizza',
                    'McAlisters Deli',
                    'McDonalds',
                    'Moes Southwest Grill',
                    'Panda Express',
                    'Panera Bread',
                    'Papa Johns',
                    'Papa Murphys',
                    'Pizza Hut',
                    'Popeyes Louisiana Kitchen',
                    'QDOBA',
                    'Raising Canes',
                    'Sonic Drive-in',
                    'Starbucks',
                    'Subway',
                    'Taco Bell',
                    'Tim Hortons',
                    'Tropical Smoothie Cafe',
                    'Wendys',
                    'Whataburger',
                    'White Castle',
                    'Wingstop',
                    'Zaxbys'], fontsize=6)

# Show the plot
plt.tight_layout()
plt.show()

# %%
correlation_matrix = income_df.corrwith(fast_food_df)
print(correlation_matrix)
# Out:
# 2020 Margin of Error                                    NaN
# 2020 Median Income                                      NaN
# 2020 Number of Households (Thousands)                   NaN
# 2021 Margin of Error                                    NaN
# 2021 Median Income                                      NaN
# 2021 Number of Households (Thousands)                   NaN
# 2021 Total Units                                        NaN
# Average Sales per Unit 2021 (Thousands - U.S Dollars)   NaN
# Company Stores                                          NaN
# Estimated Margin of Error for Percent Change            NaN
# Fast-Food Chains                                        NaN
# Franchised Stores                                       NaN
# Percent Change 2020 to 2021                             NaN
# Total Change in Units from 2020                         NaN
# Types of Households                                     NaN
# U.S. Systemwide Sales 2021 (Millions - U.S Dollars)     NaN
# ...

# %%
correlation_matrix = income_df.corrwith(fast_food_df_2020)   
print(correlation_matrix)
# Out:
# 2020 Margin of Error                                    NaN
# 2020 Median Income                                      NaN
# 2020 Number of Households (Thousands)                   NaN
# 2020 Total Units                                        NaN
# 2021 Margin of Error                                    NaN
# 2021 Median Income                                      NaN
# 2021 Number of Households (Thousands)                   NaN
# Average Sales per Unit 2020 (Thousands - U.S Dollars)   NaN
# Company Stores                                          NaN
# Estimated Margin of Error for Percent Change            NaN
# Fast-Food Chains                                        NaN
# Franchised Stores                                       NaN
# Percent Change 2020 to 2021                             NaN
# Total Change in Units from 2019                         NaN
# Types of Households                                     NaN
# U.S. Systemwide Sales 2020 (Millions - U.S Dollars)     NaN
# ...
